# %% [markdown]
# # Lab11. Exploration of Convolutional Neural Networks Design

# %%
import tensorflow as tf
from keras import *
from keras.datasets import mnist
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from keras.models import Sequential

# %%
(train_X, train_y), (test_X, test_y) = mnist.load_data()

# %%
print('X_train: ' + str(train_X.shape))
print('Y_train: ' + str(train_y.shape))
print('X_test:  '  + str(test_X.shape))
print('Y_test:  '  + str(test_y.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
from matplotlib import pyplot
for i in range(9):
  pyplot.subplot(330 + 1 + i)
  pyplot.imshow(train_X[i], cmap=pyplot.get_cmap('gray'))
  pyplot.show()

# %%
print(train_y[444])
plt.imshow(train_X[444])
# Out:
# 2

# %%
train_X = train_X.astype('float32')/255
test_X = test_X.astype('float32')/255

# %%
train_X.shape
# Out:
# (60000, 28, 28)

# %%
train_y.shape
# Out:
# (60000,)

# %%
# increasing number of filters

# %%
def mod(n):
 model = Sequential()
 model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
 model.add(Flatten())
 model.add(Dense(10,activation = 'softmax'))
 return model

# %%
model1=mod(4)
model1.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model1.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 17s 7ms/step - loss: 0.1592 - accuracy: 0.9531 - val_loss: 0.0755 - val_accuracy: 0.9756
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0567 - accuracy: 0.9830 - val_loss: 0.0653 - val_accuracy: 0.9780
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0360 - accuracy: 0.9890 - val_loss: 0.0688 - val_accuracy: 0.9788
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0230 - accuracy: 0.9932 - val_loss: 0.0679 - val_accuracy: 0.9802
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.0710 - val_accuracy: 0.9808

# %%
model2=mod(32)
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.1537 - accuracy: 0.9536 - val_loss: 0.0897 - val_accuracy: 0.9710
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0582 - accuracy: 0.9827 - val_loss: 0.0664 - val_accuracy: 0.9794
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0372 - accuracy: 0.9887 - val_loss: 0.0684 - val_accuracy: 0.9786
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0250 - accuracy: 0.9918 - val_loss: 0.0684 - val_accuracy: 0.9805
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.0763 - val_accuracy: 0.9801

# %%
model3=mod(128)
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1604 - accuracy: 0.9527 - val_loss: 0.0764 - val_accuracy: 0.9757
# Epoch 2/5
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0578 - accuracy: 0.9830 - val_loss: 0.0700 - val_accuracy: 0.9793
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0374 - accuracy: 0.9881 - val_loss: 0.0629 - val_accuracy: 0.9810
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0248 - accuracy: 0.9922 - val_loss: 0.0648 - val_accuracy: 0.9804
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.0732 - val_accuracy: 0.9796

# %%
model4=mod(512)
model4.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model4.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1518 - accuracy: 0.9545 - val_loss: 0.0764 - val_accuracy: 0.9761
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0577 - accuracy: 0.9821 - val_loss: 0.0704 - val_accuracy: 0.9775
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0359 - accuracy: 0.9891 - val_loss: 0.0687 - val_accuracy: 0.9800
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.0650 - val_accuracy: 0.9807
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0164 - accuracy: 0.9951 - val_loss: 0.0727 - val_accuracy: 0.9788

# %%
model4=mod(2056)
model4.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model4.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.1554 - accuracy: 0.9539 - val_loss: 0.0697 - val_accuracy: 0.9770
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0552 - accuracy: 0.9832 - val_loss: 0.0646 - val_accuracy: 0.9792
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0355 - accuracy: 0.9889 - val_loss: 0.0696 - val_accuracy: 0.9795
# Epoch 4/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0229 - accuracy: 0.9932 - val_loss: 0.0628 - val_accuracy: 0.9798
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0168 - accuracy: 0.9945 - val_loss: 0.0673 - val_accuracy: 0.9800

# %%
#  Increasing number of layers

# %%
def mod(n):
 model = Sequential()
 for i in range(n):
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
 model.add(Flatten())
 model.add(Dense(10,activation = 'softmax'))
 return model

# %%
model2=mod(2)
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5,batch_size=64, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 938/938 [==============================] - 7s 6ms/step - loss: 0.1266 - accuracy: 0.9614 - val_loss: 0.0528 - val_accuracy: 0.9834
# Epoch 2/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0431 - accuracy: 0.9865 - val_loss: 0.0538 - val_accuracy: 0.9839
# Epoch 3/5
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0284 - accuracy: 0.9911 - val_loss: 0.0464 - val_accuracy: 0.9856
# Epoch 4/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0503 - val_accuracy: 0.9856
# Epoch 5/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.0574 - val_accuracy: 0.9866

# %%
model3=mod(3)
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5,batch_size=64, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 938/938 [==============================] - 8s 6ms/step - loss: 0.1151 - accuracy: 0.9653 - val_loss: 0.0562 - val_accuracy: 0.9807
# Epoch 2/5
# 938/938 [==============================] - 6s 7ms/step - loss: 0.0390 - accuracy: 0.9876 - val_loss: 0.0384 - val_accuracy: 0.9871
# Epoch 3/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0223 - accuracy: 0.9933 - val_loss: 0.0441 - val_accuracy: 0.9879
# Epoch 4/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0158 - accuracy: 0.9946 - val_loss: 0.0382 - val_accuracy: 0.9882
# Epoch 5/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0585 - val_accuracy: 0.9840

# %%
model4=mod(4)
model4.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model4.fit(train_X,train_y,epochs=5,batch_size=64, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 938/938 [==============================] - 10s 8ms/step - loss: 0.1151 - accuracy: 0.9645 - val_loss: 0.0406 - val_accuracy: 0.9863
# Epoch 2/5
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0391 - accuracy: 0.9880 - val_loss: 0.0376 - val_accuracy: 0.9869
# Epoch 3/5
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.0422 - val_accuracy: 0.9873
# Epoch 4/5
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.0341 - val_accuracy: 0.9905
# Epoch 5/5
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 0.0478 - val_accuracy: 0.9870

# %%
# Size of filters

# %%
def mod(n, f1):
 model = Sequential()
 for i in range(n):
  model.add(Conv2D(32, (f1, f1), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
 model.add(Flatten())
 model.add(Dense(10,activation = 'softmax'))
 return model

# %%
model4=mod(2, 3)
model4.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model4.fit(train_X,train_y,epochs=5,batch_size=64, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 938/938 [==============================] - 7s 6ms/step - loss: 0.1228 - accuracy: 0.9630 - val_loss: 0.0478 - val_accuracy: 0.9858
# Epoch 2/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0444 - accuracy: 0.9863 - val_loss: 0.0502 - val_accuracy: 0.9828
# Epoch 3/5
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0279 - accuracy: 0.9910 - val_loss: 0.0420 - val_accuracy: 0.9887
# Epoch 4/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0183 - accuracy: 0.9940 - val_loss: 0.0447 - val_accuracy: 0.9858
# Epoch 5/5
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0506 - val_accuracy: 0.9864

# %%
model4=mod(2, 5)
model4.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model4.fit(train_X,train_y,epochs=5,batch_size=64, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 938/938 [==============================] - 6s 5ms/step - loss: 0.1144 - accuracy: 0.9648 - val_loss: 0.0512 - val_accuracy: 0.9825
# Epoch 2/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0398 - accuracy: 0.9878 - val_loss: 0.0404 - val_accuracy: 0.9875
# Epoch 3/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0246 - accuracy: 0.9920 - val_loss: 0.0437 - val_accuracy: 0.9870
# Epoch 4/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.0423 - val_accuracy: 0.9881
# Epoch 5/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.0479 - val_accuracy: 0.9869

# %%
model4=mod(2, 7)
model4.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model4.fit(train_X,train_y,epochs=5,batch_size=64, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 938/938 [==============================] - 7s 6ms/step - loss: 0.1266 - accuracy: 0.9606 - val_loss: 0.0464 - val_accuracy: 0.9860
# Epoch 2/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0406 - accuracy: 0.9871 - val_loss: 0.0350 - val_accuracy: 0.9885
# Epoch 3/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 0.0374 - val_accuracy: 0.9889
# Epoch 4/5
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0206 - accuracy: 0.9932 - val_loss: 0.0356 - val_accuracy: 0.9892
# Epoch 5/5
# 938/938 [==============================] - 5s 5ms/step - loss: 0.0157 - accuracy: 0.9949 - val_loss: 0.0447 - val_accuracy: 0.9875

# %%
# Activation function

# %%
def mod(n,act):
 model = Sequential()
 for i in range(n):
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
 model.add(Flatten())
 model.add(Dense(10,activation = 'softmax'))
 return model

# %%
model=mod(2,'tanh')
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.1133 - accuracy: 0.9656 - val_loss: 0.0459 - val_accuracy: 0.9843
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0395 - accuracy: 0.9876 - val_loss: 0.0431 - val_accuracy: 0.9859
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0241 - accuracy: 0.9919 - val_loss: 0.0486 - val_accuracy: 0.9860
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.0497 - val_accuracy: 0.9868
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.0508 - val_accuracy: 0.9867

# %%
score = model.evaluate(test_X, test_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.050811994820833206
# Test accuracy: 0.9866999983787537

# %%
model1=mod(2,'relu')
model1.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model1.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1187 - accuracy: 0.9639 - val_loss: 0.0565 - val_accuracy: 0.9831
# Epoch 2/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0432 - accuracy: 0.9867 - val_loss: 0.0555 - val_accuracy: 0.9830
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0277 - accuracy: 0.9911 - val_loss: 0.0489 - val_accuracy: 0.9861
# Epoch 4/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.0558 - val_accuracy: 0.9852
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0556 - val_accuracy: 0.9853

# %%
score = model1.evaluate(test_X, test_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.05561318248510361
# Test accuracy: 0.9853000044822693

# %%
# Filter size combinations

# %%
model2 = Sequential()
model2.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=16, kernel_size=(5,5), activation='relu'))
model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 5ms/step - loss: 0.1310 - accuracy: 0.9602 - val_loss: 0.0547 - val_accuracy: 0.9819
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0480 - accuracy: 0.9854 - val_loss: 0.0467 - val_accuracy: 0.9857
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0327 - accuracy: 0.9897 - val_loss: 0.0369 - val_accuracy: 0.9876
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0238 - accuracy: 0.9926 - val_loss: 0.0431 - val_accuracy: 0.9874
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 0.0440 - val_accuracy: 0.9876

# %%
model2 = Sequential()
model2.add(Conv2D(filters=16, kernel_size=(5, 5), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=16, kernel_size=(7, 7), activation='relu'))
model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 13s 6ms/step - loss: 0.1253 - accuracy: 0.9621 - val_loss: 0.0572 - val_accuracy: 0.9817
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0490 - accuracy: 0.9852 - val_loss: 0.0382 - val_accuracy: 0.9872
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0341 - accuracy: 0.9895 - val_loss: 0.0584 - val_accuracy: 0.9827
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0253 - accuracy: 0.9917 - val_loss: 0.0387 - val_accuracy: 0.9878
# Epoch 5/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.0371 - val_accuracy: 0.9887

# %%
model2 = Sequential()
model2.add(Conv2D(filters=16, kernel_size=(7, 7), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=16, kernel_size=(9, 9), activation='relu'))
model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.1485 - accuracy: 0.9554 - val_loss: 0.0709 - val_accuracy: 0.9797
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0576 - accuracy: 0.9827 - val_loss: 0.0540 - val_accuracy: 0.9829
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0431 - accuracy: 0.9865 - val_loss: 0.0437 - val_accuracy: 0.9863
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0329 - accuracy: 0.9891 - val_loss: 0.0403 - val_accuracy: 0.9878
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0258 - accuracy: 0.9916 - val_loss: 0.0457 - val_accuracy: 0.9870

# %%
model2 = Sequential()
model2.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=16, kernel_size=(7, 7), activation='relu'))
model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 21s 9ms/step - loss: 0.1266 - accuracy: 0.9620 - val_loss: 0.0408 - val_accuracy: 0.9862
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0446 - accuracy: 0.9861 - val_loss: 0.0367 - val_accuracy: 0.9879
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0306 - accuracy: 0.9902 - val_loss: 0.0404 - val_accuracy: 0.9870
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0197 - accuracy: 0.9935 - val_loss: 0.0335 - val_accuracy: 0.9899
# Epoch 5/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.0412 - val_accuracy: 0.9902

# %%
model2 = Sequential()
model2.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=16, kernel_size=(9, 9), activation='relu'))
model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.1297 - accuracy: 0.9604 - val_loss: 0.0449 - val_accuracy: 0.9852
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0445 - accuracy: 0.9862 - val_loss: 0.0438 - val_accuracy: 0.9855
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.0414 - val_accuracy: 0.9876
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0229 - accuracy: 0.9926 - val_loss: 0.0317 - val_accuracy: 0.9901
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0164 - accuracy: 0.9944 - val_loss: 0.0363 - val_accuracy: 0.9902

# %%
model2 = Sequential()
model2.add(Conv2D(filters=16, kernel_size=(5, 5), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 16s 7ms/step - loss: 0.1411 - accuracy: 0.9586 - val_loss: 0.0762 - val_accuracy: 0.9756
# Epoch 2/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0520 - accuracy: 0.9840 - val_loss: 0.0535 - val_accuracy: 0.9838
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0383 - accuracy: 0.9881 - val_loss: 0.0456 - val_accuracy: 0.9856
# Epoch 4/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0274 - accuracy: 0.9915 - val_loss: 0.0511 - val_accuracy: 0.9848
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0223 - accuracy: 0.9926 - val_loss: 0.0441 - val_accuracy: 0.9875

# %%
# Layer-filter combination

# %%
model2 = Sequential()
model2.add(Conv2D(filters=2, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=4, kernel_size=(7, 7), activation='relu'))
model2.add(Conv2D(filters=8, kernel_size=(7, 7), activation='relu'))
model2.add(Conv2D(filters=16, kernel_size=(7, 7), activation='relu'))
model2.add(Conv2D(filters=32, kernel_size=(7, 7), activation='relu'))


model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 15s 6ms/step - loss: 0.2428 - accuracy: 0.9232 - val_loss: 0.0834 - val_accuracy: 0.9741
# Epoch 2/5
# 1875/1875 [==============================] - 20s 11ms/step - loss: 0.0841 - accuracy: 0.9739 - val_loss: 0.0568 - val_accuracy: 0.9826
# Epoch 3/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0659 - accuracy: 0.9794 - val_loss: 0.0654 - val_accuracy: 0.9785
# Epoch 4/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0563 - accuracy: 0.9830 - val_loss: 0.0632 - val_accuracy: 0.9805
# Epoch 5/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0489 - accuracy: 0.9850 - val_loss: 0.0626 - val_accuracy: 0.9806

# %%
model2 = Sequential()
model2.add(Conv2D(filters=8, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=16, kernel_size=(7, 7), activation='relu'))
model2.add(Conv2D(filters=32, kernel_size=(7, 7), activation='relu'))
model2.add(Conv2D(filters=4, kernel_size=(7, 7), activation='relu'))
model2.add(Conv2D(filters=2, kernel_size=(7, 7), activation='relu'))


model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 15s 6ms/step - loss: 1.2626 - accuracy: 0.5595 - val_loss: 0.4425 - val_accuracy: 0.8784
# Epoch 2/5
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3325 - accuracy: 0.9153 - val_loss: 0.2120 - val_accuracy: 0.9450
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.2013 - accuracy: 0.9495 - val_loss: 0.1614 - val_accuracy: 0.9604
# Epoch 4/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1528 - accuracy: 0.9615 - val_loss: 0.1282 - val_accuracy: 0.9654
# Epoch 5/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.1259 - accuracy: 0.9673 - val_loss: 0.1279 - val_accuracy: 0.9666

# %%
model2 = Sequential()
model2.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=4, kernel_size=(3, 3), activation='relu'))
model2.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model2.add(Conv2D(filters=4, kernel_size=(3, 3), activation='relu'))
model2.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'))


model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 18s 7ms/step - loss: 0.1520 - accuracy: 0.9534 - val_loss: 0.0585 - val_accuracy: 0.9812
# Epoch 2/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0559 - accuracy: 0.9832 - val_loss: 0.0454 - val_accuracy: 0.9857
# Epoch 3/5
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0382 - accuracy: 0.9880 - val_loss: 0.0422 - val_accuracy: 0.9868
# Epoch 4/5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0293 - accuracy: 0.9905 - val_loss: 0.0442 - val_accuracy: 0.9874
# Epoch 5/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0212 - accuracy: 0.9932 - val_loss: 0.0450 - val_accuracy: 0.9876

# %%
model2 = Sequential()
model2.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model2.add(Conv2D(filters=16, kernel_size=(3, 3), activation='relu'))
model2.add(Conv2D(filters=8, kernel_size=(3,3), activation='relu'))
model2.add(Conv2D(filters=4, kernel_size=(3, 3), activation='relu'))
model2.add(Conv2D(filters=8, kernel_size=(3, 3), activation='relu'))
model2.add(Conv2D(filters=8, kernel_size=(3, 3), activation='relu'))



model2.add(Flatten())
model2.add(Dense(10,activation = 'softmax'))
model2.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model2.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 16s 7ms/step - loss: 0.1885 - accuracy: 0.9434 - val_loss: 0.0876 - val_accuracy: 0.9738
# Epoch 2/5
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0724 - accuracy: 0.9781 - val_loss: 0.0558 - val_accuracy: 0.9811
# Epoch 3/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0548 - accuracy: 0.9833 - val_loss: 0.0549 - val_accuracy: 0.9835
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0452 - accuracy: 0.9855 - val_loss: 0.0482 - val_accuracy: 0.9846
# Epoch 5/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0379 - accuracy: 0.9884 - val_loss: 0.0434 - val_accuracy: 0.9874

# %%
# Influence of Striding

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(3, 3),strides=(2,2), activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(5,5),strides=(2,2), activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.1967 - accuracy: 0.9420 - val_loss: 0.0713 - val_accuracy: 0.9789
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0675 - accuracy: 0.9796 - val_loss: 0.0540 - val_accuracy: 0.9837
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0487 - accuracy: 0.9848 - val_loss: 0.0538 - val_accuracy: 0.9837
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0385 - accuracy: 0.9882 - val_loss: 0.0487 - val_accuracy: 0.9846
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0314 - accuracy: 0.9901 - val_loss: 0.0436 - val_accuracy: 0.9865

# %%
score = model3.evaluate(test_X, test_y, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.043628498911857605
# Test accuracy: 0.9865000247955322

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(5, 5),strides=(2,2), activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(5,5),strides=(2,2), activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 4ms/step - loss: 0.2053 - accuracy: 0.9394 - val_loss: 0.0734 - val_accuracy: 0.9790
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0727 - accuracy: 0.9787 - val_loss: 0.0660 - val_accuracy: 0.9790
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0520 - accuracy: 0.9838 - val_loss: 0.0510 - val_accuracy: 0.9847
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0401 - accuracy: 0.9876 - val_loss: 0.0443 - val_accuracy: 0.9870
# Epoch 5/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0323 - accuracy: 0.9900 - val_loss: 0.0455 - val_accuracy: 0.9867

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(7, 7),strides=(2,2), activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(7, 7),strides=(2,2), activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1949 - accuracy: 0.9426 - val_loss: 0.0756 - val_accuracy: 0.9764
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0672 - accuracy: 0.9794 - val_loss: 0.0601 - val_accuracy: 0.9798
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0467 - accuracy: 0.9858 - val_loss: 0.0456 - val_accuracy: 0.9855
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0364 - accuracy: 0.9881 - val_loss: 0.0363 - val_accuracy: 0.9875
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0277 - accuracy: 0.9912 - val_loss: 0.0360 - val_accuracy: 0.9889

# %%
# Influence of padding

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(3, 3),padding = 'same', activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(5,5),padding = 'same', activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1147 - accuracy: 0.9654 - val_loss: 0.0428 - val_accuracy: 0.9851
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0419 - accuracy: 0.9868 - val_loss: 0.0400 - val_accuracy: 0.9869
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0263 - accuracy: 0.9912 - val_loss: 0.0491 - val_accuracy: 0.9852
# Epoch 4/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.0434 - val_accuracy: 0.9866
# Epoch 5/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0465 - val_accuracy: 0.9864

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(3, 3),padding = 'valid', activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(5,5),padding = 'Valid', activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 15s 7ms/step - loss: 0.1147 - accuracy: 0.9653 - val_loss: 0.0411 - val_accuracy: 0.9868
# Epoch 2/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0418 - accuracy: 0.9875 - val_loss: 0.0382 - val_accuracy: 0.9860
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0274 - accuracy: 0.9910 - val_loss: 0.0354 - val_accuracy: 0.9886
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0182 - accuracy: 0.9941 - val_loss: 0.0451 - val_accuracy: 0.9864
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.0397 - val_accuracy: 0.9888

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(5, 5),padding = 'same', activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(5,5),padding = 'same', activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.1133 - accuracy: 0.9665 - val_loss: 0.0485 - val_accuracy: 0.9846
# Epoch 2/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0410 - accuracy: 0.9872 - val_loss: 0.0347 - val_accuracy: 0.9892
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0261 - accuracy: 0.9915 - val_loss: 0.0433 - val_accuracy: 0.9879
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0190 - accuracy: 0.9936 - val_loss: 0.0451 - val_accuracy: 0.9874
# Epoch 5/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0126 - accuracy: 0.9956 - val_loss: 0.0403 - val_accuracy: 0.9891

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(5, 5),padding = 'valid', activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(5,5),padding = 'valid', activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1091 - accuracy: 0.9671 - val_loss: 0.0378 - val_accuracy: 0.9875
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0394 - accuracy: 0.9876 - val_loss: 0.0334 - val_accuracy: 0.9886
# Epoch 3/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0256 - accuracy: 0.9917 - val_loss: 0.0397 - val_accuracy: 0.9888
# Epoch 4/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.0343 - val_accuracy: 0.9880
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.0439 - val_accuracy: 0.9877

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(7, 7),padding = 'same', activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(7,7),padding = 'same', activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 12s 5ms/step - loss: 0.1056 - accuracy: 0.9675 - val_loss: 0.0332 - val_accuracy: 0.9891
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0411 - accuracy: 0.9876 - val_loss: 0.0482 - val_accuracy: 0.9846
# Epoch 3/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0267 - accuracy: 0.9919 - val_loss: 0.0300 - val_accuracy: 0.9909
# Epoch 4/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.0322 - val_accuracy: 0.9908
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.0420 - val_accuracy: 0.9882

# %%
model3 = Sequential()
model3.add(Conv2D(filters=32, kernel_size=(7, 7),padding = 'valid', activation='relu', input_shape = (28,28,1)))
model3.add(Conv2D(filters=32, kernel_size=(7,7),padding = 'valid', activation='relu'))
model3.add(Flatten())
model3.add(Dense(10,activation = 'softmax'))
model3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model3.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.1172 - accuracy: 0.9644 - val_loss: 0.0415 - val_accuracy: 0.9868
# Epoch 2/5
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0414 - accuracy: 0.9872 - val_loss: 0.0377 - val_accuracy: 0.9878
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0305 - accuracy: 0.9907 - val_loss: 0.0292 - val_accuracy: 0.9909
# Epoch 4/5
# 1875/1875 [==============================] - 17s 9ms/step - loss: 0.0215 - accuracy: 0.9934 - val_loss: 0.0282 - val_accuracy: 0.9903
# Epoch 5/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.0320 - val_accuracy: 0.9903

# %%
# Influence of pooling

# %%
model7 = Sequential()
model7.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=(28,28,1)))
model7.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=(28,28,1)))
model7.add(MaxPooling2D(pool_size=(2,2)))
model7.add(Flatten())
model7.add(Dense(10,activation = 'softmax'))
model7.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model7.fit(train_X,train_y,epochs=5,validation_data=(test_X, test_y) )
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.1241 - accuracy: 0.9633 - val_loss: 0.0411 - val_accuracy: 0.9864
# Epoch 2/5
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0445 - accuracy: 0.9861 - val_loss: 0.0392 - val_accuracy: 0.9869
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0321 - accuracy: 0.9897 - val_loss: 0.0353 - val_accuracy: 0.9881
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0239 - accuracy: 0.9925 - val_loss: 0.0378 - val_accuracy: 0.9876
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 0.0322 - val_accuracy: 0.9893

# %%
model8 = Sequential()
model8.add(Conv2D(filters=32, kernel_size=(7,7), activation='relu', input_shape=(28,28,1)))
model8.add(Conv2D(filters=32, kernel_size=(7,7), activation='relu'))
model8.add(MaxPooling2D(pool_size=(2,2)))
model8.add(Flatten())
model8.add(Dense(10,activation = 'softmax'))
model8.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model8.fit(train_X,train_y,epochs=5, validation_data=(test_X, test_y))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1280 - accuracy: 0.9609 - val_loss: 0.0475 - val_accuracy: 0.9834
# Epoch 2/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0456 - accuracy: 0.9863 - val_loss: 0.0479 - val_accuracy: 0.9849
# Epoch 3/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0333 - accuracy: 0.9899 - val_loss: 0.0393 - val_accuracy: 0.9879
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0262 - accuracy: 0.9919 - val_loss: 0.0303 - val_accuracy: 0.9906
# Epoch 5/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0206 - accuracy: 0.9937 - val_loss: 0.0305 - val_accuracy: 0.9907
